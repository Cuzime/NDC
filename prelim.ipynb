# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.image as mpimg
import random
import math

import tensorflow_datasets as tfds
from tensorflow import keras 
from keras import layers
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

from keras.layers.convolutional.conv2d_transpose import Conv2DTranspose
from keras.layers.reshaping.up_sampling2d import UpSampling2D

import wandb
from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

# %% [markdown]
# ## DSS2 FITS files

# %%
from astropy.io import fits 

blue_fx = fits.open('prelim_dss_data/irsa.ipac.caltech.edu/data/DSS/images/dss2blue/dss2blue_XJ665.fits', memmap=True)
blue_img = blue_fx[0].data
print(np.shape(blue_img))

red_fx = fits.open('/Users/andrewgoh/Desktop/NDC/prelim_dss_data/irsa.ipac.caltech.edu/data/DSS/images/dss2red/dss2red_XP665.fits', memmap=True)
red_img = red_fx[0].data
print(np.shape(red_img))

ir_fx = fits.open('/Users/andrewgoh/Desktop/NDC/prelim_dss_data/irsa.ipac.caltech.edu/data/DSS/images/dss2ir/dss2ir_XI665.fits', memmap = True)
ir_img = ir_fx[0].data
print(np.shape(ir_img))

plt.figure(figsize = (30,30))
plt.imshow(red_img, cmap = 'gray')
# Out:
# (23040, 23040)
# (23040, 23040)
# (23040, 23040)
